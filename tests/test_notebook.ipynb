# %%
x = 10
print(f'Set x = {x}')

# %%
y = x * 2
print(f'Set y = x * 2 = {y}')

# %%
print(f'x = {x}, y = {y}')

# %% [markdown]
# ## This is a markdown cell
#
# It should be skipped during execution.

# %%
z = x + y
print(f'z = x + y = {z}')

# %%
# This cell can be re-run to test state persistence
result = x + y + z
print(f'result = x + y + z = {result}')
