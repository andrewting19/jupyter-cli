# %%
x = 10
print(f'Set x = {x}')
# Out:
# Set x = 10

# %%
y = x * 2
print(f'Set y = {y}')
# Out:
# Set y = 20

# %%
42
# Out:
# 42

# %%
undefined_var
# Out:
# NameError: name 'undefined_var' is not defined
